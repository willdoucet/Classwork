# %%
import requests
import json
import pandas as pd
from pprint import pprint

# %%
url = 'https://www.quandl.com/api/v3/datasets/ZILLOW/Z92104_ZHVIAH?api_key=cWA44PEoGd6yLPCCzpf3'

data = requests.get(url).json()

# %%
pprint(data)
# Out:
# {'dataset': {'collapse': None,
#              'column_index': None,
#              'column_names': ['Date', 'Value'],
#              'data': [['2018-09-30', 616600.0],
#                       ['2018-08-31', 613600.0],
#                       ['2018-07-31', 610500.0],
#                       ['2018-06-30', 610600.0],
#                       ['2018-05-31', 613600.0],
#                       ['2018-04-30', 616000.0],
#                       ['2018-03-31', 616400.0],
#                       ['2018-02-28', 612600.0],
#                       ['2018-01-31', 605200.0],
#                       ['2017-12-31', 598800.0],
#                       ['2017-11-30', 595500.0],
#                       ['2017-10-31', 592000.0],
#                       ['2017-09-30', 588400.0],
#                       ['2017-08-31', 584400.0],
#                       ['2017-07-31', 581800.0],
#                       ['2017-06-30', 579700.0],
#                       ['2017-05-31', 575200.0],
# ...

# %%
pprint(data['dataset']['data'][0][1])
# Out:
# 616600.0
